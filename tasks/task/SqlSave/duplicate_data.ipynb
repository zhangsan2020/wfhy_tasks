# %%
import pymongo

# %%
import pandas as pd

# %%
pymongo.MongoClient?

# %%
mongo_cli = pymongo.MongoClient('127.0.0.1',27017)

# %%
db = mongo_cli['wfhy']
col_chictr = db.chictr

# %%
pd.DataFrame(list(col_chictr.find()))
# Out:
#                             _id    name            phone  \
# 0      630763a0fa3a0a834f767967     李文志      18045159998
# 1      630763a1fa3a0a834f767968     管文瑜      18953117225
# 2      630763a3fa3a0a834f767969      陈璇      13751771283
# 3      630763a3fa3a0a834f76796a     邱小玲      13751877836
# 4      630763a4fa3a0a834f76796b     潘韶霞     010-82195393
# ...                         ...     ...              ...
# 92668  63164f2605b2acf8e9693a76     夏照华  +86 13823135410
# 92669  63164f2705b2acf8e9693a78     李国才  +86 13143378727
# 92670  63164f2805b2acf8e9693a79     袁正勇  +86 13688354162
# 92671  63164f2805b2acf8e9693a7a  袁正勇/唐伟  +86 13688354162
# 92672  63164f2705b2acf8e9693a77      魏巍  +86 18520698366
#
#                           email  \
# 0             wenzhili9@126.com
# 1              850285685@qq.com
# 2              406625227@qq.com
# 3          linglingjojo@163.com
# 4        panshaoxia@vip.163.com
# ...                         ...
# 92668     daoren_000113@126.com
# ...
