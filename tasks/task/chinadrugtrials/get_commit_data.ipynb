# %%
import pandas as pd
import pymongo

# %%
mongo_cli = pymongo.MongoClient(host='127.0.0.1',port=27017)
col = mongo_cli['wfhy_update']['chinadrug_new']

# %%
df = pd.DataFrame(list(col.find()))

# %%
df.head()
# Out:
#                         _id name        phone                      email  \
# 0  632aafec985ca1c256ffc21e   李挺  13587876896      liting1021@aliyun.com
# 1  632aafef985ca1c256ffc21f  李静静  18621199185   Jingjing.Li1@covance.com
# 2  632aafef985ca1c256ffc221  曹昌翔  19602109664  cao_chang_xiang@lilly.com
# 3  632aafef985ca1c256ffc223  郭立新  13901317569            glx1218@163.com
# 4  632aaff1985ca1c256ffc225   张敏  18162978366      zhangmin@renfu.com.cn
#
#   register_num register_people register_date                company  \
# 0  CTR20222442             赵铁生    2022-09-21           温州医科大学附属第二医院
# 1  CTR20222437             李静静    2022-09-21         AstraZeneca AB
# 2  CTR20222427             曹昌翔    2022-09-21  Eli Lilly and Company
# 3  CTR20222427             曹昌翔    2022-09-21                   北京医院
# 4  CTR20222424              张敏    2022-09-20           宜昌人福药业有限责任公司
#
#             drug_name                                  drug_apply  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19172 entries, 0 to 19171
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              19172 non-null  object
#  1   name             19172 non-null  object
#  2   phone            19172 non-null  object
#  3   email            19172 non-null  object
#  4   register_num     19172 non-null  object
#  5   register_people  19172 non-null  object
#  6   register_date    19172 non-null  object
#  7   company          19172 non-null  object
#  8   drug_name        19172 non-null  object
#  9   drug_apply       19172 non-null  object
#  10  title            19172 non-null  object
#  11  drug_type        19172 non-null  object
#  12  detail_id        19172 non-null  object
#  13  page_num         19172 non-null  int64
#  14  spider_date      19172 non-null  object
#  15  landline         19172 non-null  object
# dtypes: int64(1), object(15)
# ...

# %%
df['phone'] = df['phone'].map(lambda x: x.split(' ')[1] if len(x.split(' '))>1 else x)

# %%
df.head()
# Out:
#                         _id name        phone                      email  \
# 0  632aafec985ca1c256ffc21e   李挺  13587876896      liting1021@aliyun.com
# 1  632aafef985ca1c256ffc21f  李静静  18621199185   Jingjing.Li1@covance.com
# 2  632aafef985ca1c256ffc221  曹昌翔  19602109664  cao_chang_xiang@lilly.com
# 3  632aafef985ca1c256ffc223  郭立新  13901317569            glx1218@163.com
# 4  632aaff1985ca1c256ffc225   张敏  18162978366      zhangmin@renfu.com.cn
#
#   register_num register_people register_date                company  \
# 0  CTR20222442             赵铁生    2022-09-21           温州医科大学附属第二医院
# 1  CTR20222437             李静静    2022-09-21         AstraZeneca AB
# 2  CTR20222427             曹昌翔    2022-09-21  Eli Lilly and Company
# 3  CTR20222427             曹昌翔    2022-09-21                   北京医院
# 4  CTR20222424              张敏    2022-09-20           宜昌人福药业有限责任公司
#
#             drug_name                                  drug_apply  \
# ...

# %%
df.drop(['_id','register_people','register_date','company','drug_name','drug_apply','title','drug_type','page_num'],inplace=True,axis=1)

# %%
df.head()
# Out:
#   name        phone                      email register_num  \
# 0   李挺  13587876896      liting1021@aliyun.com  CTR20222442
# 1  李静静  18621199185   Jingjing.Li1@covance.com  CTR20222437
# 2  曹昌翔  19602109664  cao_chang_xiang@lilly.com  CTR20222427
# 3  郭立新  13901317569            glx1218@163.com  CTR20222427
# 4   张敏  18162978366      zhangmin@renfu.com.cn  CTR20222424
#
#                           detail_id   spider_date      landline
# 0  3bf0e1c2cb2d4773ab313da005d8e650  202209211432
# 1  a75665d71eb4412c8d851913a50d185b  202209211432  010-57323159
# 2  57516c2bdf8c49d7af29d4baf289cfb9  202209211432  021-23020852
# 3  57516c2bdf8c49d7af29d4baf289cfb9  202209211432
# 4  1a1512df6c584b0785ca1d2a01b62c3d  202209211432  0717-6346240

# %%
df['commit_status'] = '已提交'

# %%
df
# Out:
#                name        phone                          email register_num  \
# 0                李挺  13587876896          liting1021@aliyun.com  CTR20222442
# 1               李静静  18621199185       Jingjing.Li1@covance.com  CTR20222437
# 2               曹昌翔  19602109664      cao_chang_xiang@lilly.com  CTR20222427
# 3               郭立新  13901317569                glx1218@163.com  CTR20222427
# 4                张敏  18162978366          zhangmin@renfu.com.cn  CTR20222424
# ...             ...          ...                            ...          ...
# 19167           裘福荣  13818094615             Furong_Qiu@126.com  CTR20130010
# 19168           陈云鹏                       chen.yunpeng@disha.cn  CTR20130009
# 19169  诺华医学热线（临床登记）  15811066279  clinicaltrial.cn@novartis.com  CTR20130002
# 19170           陈芳燕                             cfy@mspharm.com  CTR20130001
# 19171      吴新民，医学学士  13910616740           xmwu2784@hotmail.com  CTR20130001
#
# ...

# %%
df['commit_date'] = ''

# %%
df
# Out:
#                name        phone                          email register_num  \
# 0                李挺  13587876896          liting1021@aliyun.com  CTR20222442
# 1               李静静  18621199185       Jingjing.Li1@covance.com  CTR20222437
# 2               曹昌翔  19602109664      cao_chang_xiang@lilly.com  CTR20222427
# 3               郭立新  13901317569                glx1218@163.com  CTR20222427
# 4                张敏  18162978366          zhangmin@renfu.com.cn  CTR20222424
# ...             ...          ...                            ...          ...
# 19167           裘福荣  13818094615             Furong_Qiu@126.com  CTR20130010
# 19168           陈云鹏                       chen.yunpeng@disha.cn  CTR20130009
# 19169  诺华医学热线（临床登记）  15811066279  clinicaltrial.cn@novartis.com  CTR20130002
# 19170           陈芳燕                             cfy@mspharm.com  CTR20130001
# 19171      吴新民，医学学士  13910616740           xmwu2784@hotmail.com  CTR20130001
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19172 entries, 0 to 19171
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           19172 non-null  object
#  1   phone          19172 non-null  object
#  2   email          19172 non-null  object
#  3   register_num   19172 non-null  object
#  4   detail_id      19172 non-null  object
#  5   spider_date    19172 non-null  object
#  6   landline       19172 non-null  object
#  7   commit_status  19172 non-null  object
#  8   commit_date    19172 non-null  object
# dtypes: object(9)
# memory usage: 1.3+ MB

# %%
df.drop_d
