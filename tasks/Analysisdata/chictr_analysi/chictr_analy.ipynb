# %%
import pandas as pd
import pymongo
import matplotlib.pyplot as plt

# %%
mongo_cli = pymongo.MongoClient('127.0.0.1',27017)
col = mongo_cli['wfhy_update']['chictr_all']

# %%
df = pd.DataFrame(list(col.find()))

# %%
df.head()
# Out:
#                         _id        reg_number    reg_date update_date  \
# 0  631ff6da124714cae317db88  ChiCTR2200063604  2022-09-12  2022-09-13
# 1  631ff6dc124714cae317db89  ChiCTR2200063604  2022-09-12  2022-09-13
# 2  631ff6dd124714cae317db8a                    1990-01-01  2022-09-12
# 3  631ff6dd124714cae317db8b                    1990-01-01  2022-09-12
# 4  631ff6de124714cae317db8c                    1990-01-01  2022-09-12
#
#                         title  study_type name        phone  \
# 0        声带息肉患者术后声休时间对嗓音功能的影响        治疗研究  刘晨阳  19834515598
# 1        声带息肉患者术后声休时间对嗓音功能的影响        治疗研究  李育军  13994242096
# 2        椎弓根斜切技术在腰椎椎间孔镜手术中的应用       观察性研究  王颖慧  18235918761
# 3        椎弓根斜切技术在腰椎椎间孔镜手术中的应用       观察性研究  王颖慧  18235918761
# 4  颈肩痛患者颈椎Modic改变与K线倾斜角的相关性分析  病因学/相关因素研究  周青松  18227317808
#
#                email                sq_addr             sq_unit   spider_date  \
# 0     lcyy96@163.com       山西省太原市迎泽区新建南路56号  山西医科大学第一医院耳鼻咽喉头颈外科  202209131109
# ...

# %%
df[df.phone=='']
# Out:
# Empty DataFrame
# Columns: [_id, reg_number, reg_date, update_date, title, study_type, name, phone, email, sq_addr, sq_unit, spider_date, detail_url, url_id]
# Index: []

# %%
df[df.phone.map(lambda x: len(x.split(' '))>1)]
# Out:
#                              _id reg_number    reg_date update_date  \
# 18      631ff6e5124714cae317db9a             1990-01-01  2022-09-12
# 19      631ff6e5124714cae317db9b             1990-01-01  2022-09-12
# 38      631ff6f4124714cae317dbae             1990-01-01  2022-09-12
# 39      631ff6f4124714cae317dbaf             1990-01-01  2022-09-12
# 173     631ff747124714cae317dc35             1990-01-01  2022-09-10
# ...                          ...        ...         ...         ...
# 161692  632c064d37945a2e9d4b942a             1990-01-01  2022-09-20
# 161746  632c066c37945a2e9d4b9478             1990-01-01  2022-09-21
# 161779  632c068137945a2e9d4b94a5             1990-01-01  2022-09-21
# 161780  632c068137945a2e9d4b94a6             1990-01-01  2022-09-21
# 161787  632c068537945a2e9d4b94af             1990-01-01  2022-09-21
#
#                                            title study_type name  \
# 18      超声引导下外斜肋间肌阻滞与斜肋下腹横平面阻滞用于腹腔镜根治性胃切除术后效果的比较      观察性研究   虞琦
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161792 entries, 0 to 161791
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   _id          161792 non-null  object
#  1   reg_number   161792 non-null  object
#  2   reg_date     161792 non-null  object
#  3   update_date  161792 non-null  object
#  4   title        161792 non-null  object
#  5   study_type   161792 non-null  object
#  6   name         161792 non-null  object
#  7   phone        161792 non-null  object
#  8   email        161792 non-null  object
#  9   sq_addr      161792 non-null  object
#  10  sq_unit      83820 non-null   object
#  11  spider_date  161792 non-null  object
#  12  detail_url   161792 non-null  object
#  13  url_id       161792 non-null  int64
# dtypes: int64(1), object(13)
# memory usage: 17.3+ MB

# %%
df_phone_test = df[df.reg_number=='ChiCTR2200057734']

# %%
df_phone_test
# Out:
#                             _id        reg_number    reg_date update_date  \
# 22286  632034d6124714cae3183296  ChiCTR2200057734  2022-03-16  2022-03-16
# 22287  632034d6124714cae3183297  ChiCTR2200057734  2022-03-16  2022-03-16
#
#                                     title  study_type name             phone  \
# 22286  ANKRD36C、SREK1IP1和TMEM97在侵袭性牙周炎的作用  病因学/相关因素研究  金幼虹  +86  15979058055
# 22287  ANKRD36C、SREK1IP1和TMEM97在侵袭性牙周炎的作用  病因学/相关因素研究  金幼虹  +86  15979058055
#
#                     email       sq_addr     sq_unit   spider_date  \
# 22286  yhjin3713@sina.com  江西省南昌市福州路49号  南昌大学附属口腔医院  202209131509
# 22287  yhjin3713@sina.com  江西省南昌市福州路49号         NaN  202209131509
#
#                                               detail_url  url_id
# 22286  http://www.chictr.org.cn/showproj.aspx?proj=16...  162728
# 22287  http://www.chictr.org.cn/showproj.aspx?proj=16...  162728

# %%
df_phone_test.phone.map(lambda x: x.split(' ') if len(x.split(' '))>1 else x)
# Out:
# 22286    [+86, , 15979058055]
# 22287    [+86, , 15979058055]
# Name: phone, dtype: object

# %%
df_phone_test['phone'] = df_phone_test.phone.str.replace(' ','')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13724\2179775703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_phone_test['phone'] = df_phone_test.phone.str.replace(' ','')

# %%
df_phone_test.phone
# Out:
# 22286    +8615979058055
# 22287    +8615979058055
# Name: phone, dtype: object

# %%
df_phone_test.phone.str.extract('(1[3-9]\d{9})',expand=False)
# Out:
# 22286    15979058055
# 22287    15979058055
# Name: phone, dtype: object

# %%
df['phone'] = df.phone.str.replace(' ','')

# %%
df['phone'] = df.phone.str.extract('(1[3-9]\d{9})',expand=False)

# %%
df.head()
# Out:
#                         _id        reg_number    reg_date update_date  \
# 0  631ff6da124714cae317db88  ChiCTR2200063604  2022-09-12  2022-09-13
# 1  631ff6dc124714cae317db89  ChiCTR2200063604  2022-09-12  2022-09-13
# 2  631ff6dd124714cae317db8a                    1990-01-01  2022-09-12
# 3  631ff6dd124714cae317db8b                    1990-01-01  2022-09-12
# 4  631ff6de124714cae317db8c                    1990-01-01  2022-09-12
#
#                         title  study_type name        phone  \
# 0        声带息肉患者术后声休时间对嗓音功能的影响        治疗研究  刘晨阳  19834515598
# 1        声带息肉患者术后声休时间对嗓音功能的影响        治疗研究  李育军  13994242096
# 2        椎弓根斜切技术在腰椎椎间孔镜手术中的应用       观察性研究  王颖慧  18235918761
# 3        椎弓根斜切技术在腰椎椎间孔镜手术中的应用       观察性研究  王颖慧  18235918761
# 4  颈肩痛患者颈椎Modic改变与K线倾斜角的相关性分析  病因学/相关因素研究  周青松  18227317808
#
#                email                sq_addr             sq_unit   spider_date  \
# 0     lcyy96@163.com       山西省太原市迎泽区新建南路56号  山西医科大学第一医院耳鼻咽喉头颈外科  202209131109
# ...

# %%
df.groupby('phone').size().sort_values(ascending=False)
# Out:
# phone
# 18552880088    133
# 18980601028    114
# 18940255568     62
# 18256031820     61
# 15618108082     58
#               ...
# 15074806366      1
# 15074975485      1
# 15074985924      1
# 15074986604      1
# 19999208530      1
# Length: 69334, dtype: int64

# %%
plt.hist()

# %%
df[df.reg_number=='ChiCTR2200057734'].values
# Out:
# array([[ObjectId('632034d6124714cae3183296'), 'ChiCTR2200057734',
#         '2022-03-16', '2022-03-16', 'ANKRD36C、SREK1IP1和TMEM97在侵袭性牙周炎的作用',
#         '病因学/相关因素研究', '金幼虹', '', 'yhjin3713@sina.com', '江西省南昌市福州路49号',
#         '南昌大学附属口腔医院', '202209131509',
#         'http://www.chictr.org.cn/showproj.aspx?proj=162728', 162728],
#        [ObjectId('632034d6124714cae3183297'), 'ChiCTR2200057734',
#         '2022-03-16', '2022-03-16', 'ANKRD36C、SREK1IP1和TMEM97在侵袭性牙周炎的作用',
#         '病因学/相关因素研究', '金幼虹', '', 'yhjin3713@sina.com', '江西省南昌市福州路49号',
#         nan, '202209131509',
#         'http://www.chictr.org.cn/showproj.aspx?proj=162728', 162728]],
#       dtype=object)
