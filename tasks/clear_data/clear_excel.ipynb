# %%
import pandas as pd

# %%
df = pd.read_excel('./chictr_mid_data.xlsx')
df.head()
# Out:
#                         _id name            phone                email  \
# 0  630d66419f6c2c5e88d696bc  林慧玥      13736905896  linhuiyue65@163.com
# 1  630d63aa9f6c2c5e88d696bb   梁惠  +86 13043399766     205016168@qq.com
# 2  630d5e999f6c2c5e88d696b9  谢远俊  +86 15650969062   xieyuanj@gmail.com
# 3  630d5e999f6c2c5e88d696ba  王化宁  +86 13609161341   wanghuan88@163.com
# 4  630d5b079f6c2c5e88d696b8   敬茜  +86 13540752891    pandahi11@163.com
#
#                                           detail_url  url_id
# 0  http://www.chictr.org.cn/showproj.aspx?proj=10...  102589
# 1  http://www.chictr.org.cn/showproj.aspx?proj=10...  103620
# 2  http://www.chictr.org.cn/showproj.aspx?proj=10...  105795
# 3  http://www.chictr.org.cn/showproj.aspx?proj=10...  105795
# 4  http://www.chictr.org.cn/showproj.aspx?proj=10...  107264

# %%
df_1 = df[df['phone'].astype('str').str.contains('(\d+){11}',regex=True)]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings\accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
df_1.count()
# Out:
# _id           11623
# name          11545
# phone         11623
# email         11551
# detail_url    11623
# url_id        11623
# dtype: int64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11623 entries, 0 to 12409
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   _id         11623 non-null  object
#  1   name        11545 non-null  object
#  2   phone       11623 non-null  object
#  3   email       11551 non-null  object
#  4   detail_url  11623 non-null  object
#  5   url_id      11623 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 635.6+ KB

# %%
df_1[df_1.phone.astype('str').str.contains('010')]
# Out:
#                             _id name            phone  \
# 100    630c5ae35c6a790eb5bd9a8c  赵学千  +86 18801020372
# 195    630c5a745c6a790eb5bd9a26  任占杰  +86 13516385010
# 263    630c5a255c6a790eb5bd99de  吴安石  +86 13511010883
# 273    630c5a195c6a790eb5bd99d1  黎庆钿  +86 18820109789
# 290    630c5a055c6a790eb5bd99be  刘建勋  +86 13701090121
# ...                         ...  ...              ...
# 11594  630c15f03b7e06814977cc6b  刘爱华  +86 13601028919
# 11617  630c15de3b7e06814977cc53  左倩倩  +86 18801083647
# 12081  630c13ee3b7e06814977ca6c   张娇  +86 18801064238
# 12118  630c13d33b7e06814977ca42   于洋  +86 13370103520
# 12182  630c139d3b7e06814977ca01  段丽萍  +86 13901009183
#
#                          email  \
# 100          1305738227@qq.com
# 195          lchmz@wfmc.edu.cn
# 263        wuanshi@hotmail.com
# 273           398619503@qq.com
# 290         liujx0324@sina.com
# ...                        ...
# 11594      15901398688@163.com
# 11617         292318464@qq.com
# ...

# %%
df_1[['name','phone','email','detail_url']].to_excel('c.xlsx',encoding='utf-8',index=False)
