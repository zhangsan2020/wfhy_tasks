# %%
import pymongo
import pandas as pd

# %%
def get_sqldata(db,col):
#     mongo_cli = pymongo.MongoClient('47.93.86.81',27017)
    mongo_cli = pymongo.MongoClient(host='47.93.86.81',port= 27017,maxConnecting=50,authSource=db,username='zl',password='jiamianwuke2018')
    col = mongo_cli[db][col]
    df = pd.DataFrame(list(col.find()))
    print(df)
    return df

# %%
df = get_sqldata('wfhy_commit','cme_commit')
df.info()
# Out:
#                             _id         project_num  \
# 0      63e1f066b1072cadf95d9e0f  2023-01-02-001 (国)
# 1      63e1f066b1072cadf95d9e14  2023-01-03-001 (国)
# 2      63e1f066b1072cadf95d9e16  2023-01-03-003 (国)
# 3      63e1f066b1072cadf95d9e18  2023-01-03-005 (国)
# 4      63e1f066b1072cadf95d9e19  2023-01-03-006 (国)
# ...                         ...                 ...
# 12907  63e1f9fa1f5c8d730a442dbe  2022-24-04-002 (国)
# 12908  63e1f9fa1f5c8d730a442dc1  2022-24-04-005 (国)
# 12909  63e1f9fa1f5c8d730a442dca  2022-24-04-014 (国)
# 12910  63e1f9fa1f5c8d730a442dd3  2022-24-04-023 (国)
# 12911  63e1f9fa1f5c8d730a442dd5  2022-24-04-025 (国)
#
#                      project_name                     unit name        phone  \
# 0          中国解剖学会第八届解剖学技术年会及技术培训会       中国解剖学会科技咨询与开发工作委员会  易西南  13398976729
# 1                     天府医学遗传学学术会议         四川省医学科学院·四川省人民医院  杨正林  13981880412
# 2           中华医学会第二十一次全国医学遗传学学术年会  中华医学会医学遗传学分会、中华医学会学术会务部  徐湘民  13503020562
# 3                   遗传缺陷病的精准诊疗与进展                   上海市医学会  刘丽梅  13301856521
# 4                  医学分子遗传学的最新研究进展                 青岛大学附属医院  刘世国  18661807782
# ...                           ...                      ...  ...          ...
# 12907              临床研究规范化(GCP)培训       上海中医药大学附属岳阳中西医结合医院   周嘉  18017306677
# 12908               社会办医疗机构依法执业培训              中国非公立医疗机构协会   石滨  18980011451
# 12909     以医院章程建设为统领    推动医院高质量发展               四川大学华西第二医院  王素霞  18180609002
# 12910  机构备案制背景下区域医疗中心临床试验管理与实践学习班                上海市第五人民医院  吕飞舟  13801707800
# 12911          药物（器械）临床试验质量管理规范培训                  河南省人民医院   张伟  18538298396
#
#       student_num  cur_page  year   spider_date commit_status
# 0             100         1  2023  202302071432           未提交
# 1             200         1  2023  202302071432           未提交
# 2            1000         1  2023  202302071432           未提交
# 3             300         1  2023  202302071432           未提交
# 4              80         1  2023  202302071432           未提交
# ...           ...       ...   ...           ...           ...
# 12907         150       149  2022  202302071512           未提交
# 12908       500/期       149  2022  202302071512           未提交
# 12909         150       149  2022  202302071512           未提交
# 12910         150       149  2022  202302071512           未提交
# 12911         300       149  2022  202302071512           未提交
#
# [12912 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12912 entries, 0 to 12911
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            12912 non-null  object
#  1   project_num    12912 non-null  object
#  2   project_name   12912 non-null  object
#  3   unit           12912 non-null  object
#  4   name           12912 non-null  object
#  5   phone          12912 non-null  object
#  6   student_num    12912 non-null  object
#  7   cur_page       12912 non-null  int64
#  8   year           12912 non-null  int64
#  9   spider_date    12912 non-null  object
#  10  commit_status  12912 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 根据手机号去重

# %% [markdown]
# ## 分割手机号,得出11位数字的手机号码, 方便清洗, 否则部分 +86 xx 和  86 xx难以去重

# %%
df['phones'] = df.phones.map(lambda x: x.split(' ')[1] if len(x.split(' ')) > 1 else x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df['phones'] = df.phones.map(lambda x: x.split(' ')[1] if len(x.split(' ')) > 1 else x)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'phones'

# %%
df.head()
# Out:
#                         _id         project_num            project_name  \
# 0  63e1f066b1072cadf95d9e0f  2023-01-02-001 (国)  中国解剖学会第八届解剖学技术年会及技术培训会
# 1  63e1f066b1072cadf95d9e14  2023-01-03-001 (国)             天府医学遗传学学术会议
# 2  63e1f066b1072cadf95d9e16  2023-01-03-003 (国)   中华医学会第二十一次全国医学遗传学学术年会
# 3  63e1f066b1072cadf95d9e18  2023-01-03-005 (国)           遗传缺陷病的精准诊疗与进展
# 4  63e1f066b1072cadf95d9e19  2023-01-03-006 (国)          医学分子遗传学的最新研究进展
#
#                       unit name        phone student_num  cur_page  year  \
# 0       中国解剖学会科技咨询与开发工作委员会  易西南  13398976729         100         1  2023
# 1         四川省医学科学院·四川省人民医院  杨正林  13981880412         200         1  2023
# 2  中华医学会医学遗传学分会、中华医学会学术会务部  徐湘民  13503020562        1000         1  2023
# 3                   上海市医学会  刘丽梅  13301856521         300         1  2023
# 4                 青岛大学附属医院  刘世国  18661807782          80         1  2023
#
#     spider_date commit_status
# 0  202302071432           未提交
# 1  202302071432           未提交
# 2  202302071432           未提交
# 3  202302071432           未提交
# 4  202302071432           未提交

# %% [markdown]
# ## 判断真实手机号:  手机字符串包含为 (以 1 开始,其后有10位数字)

# %%
new_df = df[df.phone.str.contains('1(\d+){10}')]
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_14592\1980550809.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   new_df = df[df.phone.str.contains('1(\d+){10}')]

# %%
new_df.head()
# Out:
#                         _id         project_num            project_name  \
# 0  63e1f066b1072cadf95d9e0f  2023-01-02-001 (国)  中国解剖学会第八届解剖学技术年会及技术培训会
# 1  63e1f066b1072cadf95d9e14  2023-01-03-001 (国)             天府医学遗传学学术会议
# 2  63e1f066b1072cadf95d9e16  2023-01-03-003 (国)   中华医学会第二十一次全国医学遗传学学术年会
# 3  63e1f066b1072cadf95d9e18  2023-01-03-005 (国)           遗传缺陷病的精准诊疗与进展
# 4  63e1f066b1072cadf95d9e19  2023-01-03-006 (国)          医学分子遗传学的最新研究进展
#
#                       unit name        phone student_num  cur_page  year  \
# 0       中国解剖学会科技咨询与开发工作委员会  易西南  13398976729         100         1  2023
# 1         四川省医学科学院·四川省人民医院  杨正林  13981880412         200         1  2023
# 2  中华医学会医学遗传学分会、中华医学会学术会务部  徐湘民  13503020562        1000         1  2023
# 3                   上海市医学会  刘丽梅  13301856521         300         1  2023
# 4                 青岛大学附属医院  刘世国  18661807782          80         1  2023
#
#     spider_date commit_status
# 0  202302071432           未提交
# 1  202302071432           未提交
# 2  202302071432           未提交
# 3  202302071432           未提交
# 4  202302071432           未提交

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12912 entries, 0 to 12911
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            12912 non-null  object
#  1   project_num    12912 non-null  object
#  2   project_name   12912 non-null  object
#  3   unit           12912 non-null  object
#  4   name           12912 non-null  object
#  5   phone          12912 non-null  object
#  6   student_num    12912 non-null  object
#  7   cur_page       12912 non-null  int64
#  8   year           12912 non-null  int64
#  9   spider_date    12912 non-null  object
#  10  commit_status  12912 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB

# %%
new_df
# Out:
#                             _id         project_num  \
# 0      63e1f066b1072cadf95d9e0f  2023-01-02-001 (国)
# 1      63e1f066b1072cadf95d9e14  2023-01-03-001 (国)
# 2      63e1f066b1072cadf95d9e16  2023-01-03-003 (国)
# 3      63e1f066b1072cadf95d9e18  2023-01-03-005 (国)
# 4      63e1f066b1072cadf95d9e19  2023-01-03-006 (国)
# ...                         ...                 ...
# 12907  63e1f9fa1f5c8d730a442dbe  2022-24-04-002 (国)
# 12908  63e1f9fa1f5c8d730a442dc1  2022-24-04-005 (国)
# 12909  63e1f9fa1f5c8d730a442dca  2022-24-04-014 (国)
# 12910  63e1f9fa1f5c8d730a442dd3  2022-24-04-023 (国)
# 12911  63e1f9fa1f5c8d730a442dd5  2022-24-04-025 (国)
#
#                      project_name                     unit name        phone  \
# 0          中国解剖学会第八届解剖学技术年会及技术培训会       中国解剖学会科技咨询与开发工作委员会  易西南  13398976729
# 1                     天府医学遗传学学术会议         四川省医学科学院·四川省人民医院  杨正林  13981880412
# 2           中华医学会第二十一次全国医学遗传学学术年会  中华医学会医学遗传学分会、中华医学会学术会务部  徐湘民  13503020562
# 3                   遗传缺陷病的精准诊疗与进展                   上海市医学会  刘丽梅  13301856521
# 4                  医学分子遗传学的最新研究进展                 青岛大学附属医院  刘世国  18661807782
# ...                           ...                      ...  ...          ...
# 12907              临床研究规范化(GCP)培训       上海中医药大学附属岳阳中西医结合医院   周嘉  18017306677
# 12908               社会办医疗机构依法执业培训              中国非公立医疗机构协会   石滨  18980011451
# 12909     以医院章程建设为统领    推动医院高质量发展               四川大学华西第二医院  王素霞  18180609002
# 12910  机构备案制背景下区域医疗中心临床试验管理与实践学习班                上海市第五人民医院  吕飞舟  13801707800
# 12911          药物（器械）临床试验质量管理规范培训                  河南省人民医院   张伟  18538298396
#
#       student_num  cur_page  year   spider_date commit_status
# 0             100         1  2023  202302071432           未提交
# 1             200         1  2023  202302071432           未提交
# 2            1000         1  2023  202302071432           未提交
# 3             300         1  2023  202302071432           未提交
# 4              80         1  2023  202302071432           未提交
# ...           ...       ...   ...           ...           ...
# 12907         150       149  2022  202302071512           未提交
# 12908       500/期       149  2022  202302071512           未提交
# 12909         150       149  2022  202302071512           未提交
# 12910         150       149  2022  202302071512           未提交
# 12911         300       149  2022  202302071512           未提交
#
# [12912 rows x 11 columns]

# %% [markdown]
# ## 根据手机号去重,保留重复号码的第一个手机号, 这里注意keep参数，等于last为保留最后一行重复项

# %%
new_df.drop_duplicates(subset='phone',inplace=True,keep='first')

# %%
new_df
# Out:
#                             _id         project_num  \
# 0      63e1f066b1072cadf95d9e0f  2023-01-02-001 (国)
# 1      63e1f066b1072cadf95d9e14  2023-01-03-001 (国)
# 2      63e1f066b1072cadf95d9e16  2023-01-03-003 (国)
# 3      63e1f066b1072cadf95d9e18  2023-01-03-005 (国)
# 4      63e1f066b1072cadf95d9e19  2023-01-03-006 (国)
# ...                         ...                 ...
# 12907  63e1f9fa1f5c8d730a442dbe  2022-24-04-002 (国)
# 12908  63e1f9fa1f5c8d730a442dc1  2022-24-04-005 (国)
# 12909  63e1f9fa1f5c8d730a442dca  2022-24-04-014 (国)
# 12910  63e1f9fa1f5c8d730a442dd3  2022-24-04-023 (国)
# 12911  63e1f9fa1f5c8d730a442dd5  2022-24-04-025 (国)
#
#                      project_name                     unit name        phone  \
# 0          中国解剖学会第八届解剖学技术年会及技术培训会       中国解剖学会科技咨询与开发工作委员会  易西南  13398976729
# 1                     天府医学遗传学学术会议         四川省医学科学院·四川省人民医院  杨正林  13981880412
# 2           中华医学会第二十一次全国医学遗传学学术年会  中华医学会医学遗传学分会、中华医学会学术会务部  徐湘民  13503020562
# 3                   遗传缺陷病的精准诊疗与进展                   上海市医学会  刘丽梅  13301856521
# 4                  医学分子遗传学的最新研究进展                 青岛大学附属医院  刘世国  18661807782
# ...                           ...                      ...  ...          ...
# 12907              临床研究规范化(GCP)培训       上海中医药大学附属岳阳中西医结合医院   周嘉  18017306677
# 12908               社会办医疗机构依法执业培训              中国非公立医疗机构协会   石滨  18980011451
# 12909     以医院章程建设为统领    推动医院高质量发展               四川大学华西第二医院  王素霞  18180609002
# 12910  机构备案制背景下区域医疗中心临床试验管理与实践学习班                上海市第五人民医院  吕飞舟  13801707800
# 12911          药物（器械）临床试验质量管理规范培训                  河南省人民医院   张伟  18538298396
#
#       student_num  cur_page  year   spider_date commit_status
# 0             100         1  2023  202302071432           未提交
# 1             200         1  2023  202302071432           未提交
# 2            1000         1  2023  202302071432           未提交
# 3             300         1  2023  202302071432           未提交
# 4              80         1  2023  202302071432           未提交
# ...           ...       ...   ...           ...           ...
# 12907         150       149  2022  202302071512           未提交
# 12908       500/期       149  2022  202302071512           未提交
# 12909         150       149  2022  202302071512           未提交
# 12910         150       149  2022  202302071512           未提交
# 12911         300       149  2022  202302071512           未提交
#
# [12912 rows x 11 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12912 entries, 0 to 12911
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            12912 non-null  object
#  1   project_num    12912 non-null  object
#  2   project_name   12912 non-null  object
#  3   unit           12912 non-null  object
#  4   name           12912 non-null  object
#  5   phone          12912 non-null  object
#  6   student_num    12912 non-null  object
#  7   cur_page       12912 non-null  int64
#  8   year           12912 non-null  int64
#  9   spider_date    12912 non-null  object
#  10  commit_status  12912 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB

# %%
new_df_1 = new_df[new_df['commit_status'] == '未提交']

# %%
new_df_1.count()
# Out:
# _id              12912
# project_num      12912
# project_name     12912
# unit             12912
# name             12912
# phone            12912
# student_num      12912
# cur_page         12912
# year             12912
# spider_date      12912
# commit_status    12912
# dtype: int64

# %% [markdown]
# ## 简单查阅是否还有重复

# %%
new_df_1
# Out:
#                             _id         project_num  \
# 0      63e1f066b1072cadf95d9e0f  2023-01-02-001 (国)
# 1      63e1f066b1072cadf95d9e14  2023-01-03-001 (国)
# 2      63e1f066b1072cadf95d9e16  2023-01-03-003 (国)
# 3      63e1f066b1072cadf95d9e18  2023-01-03-005 (国)
# 4      63e1f066b1072cadf95d9e19  2023-01-03-006 (国)
# ...                         ...                 ...
# 12907  63e1f9fa1f5c8d730a442dbe  2022-24-04-002 (国)
# 12908  63e1f9fa1f5c8d730a442dc1  2022-24-04-005 (国)
# 12909  63e1f9fa1f5c8d730a442dca  2022-24-04-014 (国)
# 12910  63e1f9fa1f5c8d730a442dd3  2022-24-04-023 (国)
# 12911  63e1f9fa1f5c8d730a442dd5  2022-24-04-025 (国)
#
#                      project_name                     unit name        phone  \
# 0          中国解剖学会第八届解剖学技术年会及技术培训会       中国解剖学会科技咨询与开发工作委员会  易西南  13398976729
# 1                     天府医学遗传学学术会议         四川省医学科学院·四川省人民医院  杨正林  13981880412
# 2           中华医学会第二十一次全国医学遗传学学术年会  中华医学会医学遗传学分会、中华医学会学术会务部  徐湘民  13503020562
# 3                   遗传缺陷病的精准诊疗与进展                   上海市医学会  刘丽梅  13301856521
# 4                  医学分子遗传学的最新研究进展                 青岛大学附属医院  刘世国  18661807782
# ...                           ...                      ...  ...          ...
# 12907              临床研究规范化(GCP)培训       上海中医药大学附属岳阳中西医结合医院   周嘉  18017306677
# 12908               社会办医疗机构依法执业培训              中国非公立医疗机构协会   石滨  18980011451
# 12909     以医院章程建设为统领    推动医院高质量发展               四川大学华西第二医院  王素霞  18180609002
# 12910  机构备案制背景下区域医疗中心临床试验管理与实践学习班                上海市第五人民医院  吕飞舟  13801707800
# 12911          药物（器械）临床试验质量管理规范培训                  河南省人民医院   张伟  18538298396
#
#       student_num  cur_page  year   spider_date commit_status
# 0             100         1  2023  202302071432           未提交
# 1             200         1  2023  202302071432           未提交
# 2            1000         1  2023  202302071432           未提交
# 3             300         1  2023  202302071432           未提交
# 4              80         1  2023  202302071432           未提交
# ...           ...       ...   ...           ...           ...
# 12907         150       149  2022  202302071512           未提交
# 12908       500/期       149  2022  202302071512           未提交
# 12909         150       149  2022  202302071512           未提交
# 12910         150       149  2022  202302071512           未提交
# 12911         300       149  2022  202302071512           未提交
#
# [12912 rows x 11 columns]

# %% [markdown]
# ## 保存到excel中

# %% [markdown]
# ## 摘取部分数据进行存储

# %%
writer = pd.ExcelWriter(r'cme20230214.xlsx')
new_df_1.to_excel(writer,encoding='utf-8',index=False)
writer.save()
# Out:
# C:\Users\hello\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
# C:\Users\hello\AppData\Local\Temp\ipykernel_14592\1095379764.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
writer.close()
