# %%
import pandas as pd
from copy import deepcopy

# %%
df = pd.read_excel('./YIIGLE_20230208.xlsx')

# %%
df.phones
# Out:
# 0                                           13920265719
# 1                                           13954566369
# 2                                           13955155476
# 3                                           13761998036
# 4                                           18815003196
#                              ...
# 9048                                        16595800800
# 9049    13365917329/13599037497/13616632111/15880105239
# 9050                            17167100012/13201400050
# 9051                            13793555706/18905958123
# 9052                                        15580949490
# Name: phones, Length: 9053, dtype: object

# %%
df.head()
# Out:
#                                       author        date  \
# 0     ["冯婧", "张鹏", "吴雪", "楚伟可", "张依恋", "李萍"]  2021-12-15
# 1                       ["包相华", "毕珂", "史懋功"]  2021-12-20
# 2  ["项艺", "吴雯玥", "张倩倩", "王泽学", "张辅民", "孔德润"]  2021-12-15
# 3                       ["黄磊杰", "范建高", "曾静"]  2021-12-15
# 4                ["潘如菁", "宣暄", "吕明芬", "刘晶晶"]  2021-12-25
#
#                                              pdf_url  \
# 0  http://download.meddata.com.cn:8087/getCore/do...
# 1  http://download.meddata.com.cn:8087/getCore/do...
# 2  http://download.meddata.com.cn:8087/getCore/do...
# 3  http://download.meddata.com.cn:8087/getCore/do...
# 4  http://download.meddata.com.cn:8087/getCore/do...
#
#                                            file_name  need_pay  \
# 0   失代偿性肝硬化急性肾损伤进展为慢性肾脏病的临床特征及其对预后的影响_2021-12-15.pdf       NaN
# 1            山东省烟台市布鲁氏菌病发病状况调查及临床特征分析_2021-12-20.pdf       NaN
# 2  可充气球囊压迫辅助下硬化剂注射治疗38例食管-胃底静脉曲张的疗效评价_2021-12-15.pdf       NaN
# ...

# %%
# new_df = pd.DataFrame()
# temp_df = pd.DataFrame()
data_list = []

def split_rows(row):
    split_num = row['phones'].split('/')
    if len(split_num) > 1:
        data = row['phones'].split('/')
        print('这是data: ',data)
        print('发现多电话数据: ',row)
        for phone in data:
            print('开始切割数据, 结果为: ')
            row['phones'] = phone
            print(row['phones'])
            data_list.append(row.tolist())
            
#             data_list.append(row)
    else:
        data_list.append(row.tolist())
#             temp_df = temp_df.append(row)
#             print('这是temp_df: ', temp_df)
#         new_df = new_df.concat(temp_df)
#     else:
#         temp_df = temp_df.append(row)
#     print(temp_df)
#     return temp_df

# %%
df.apply(split_rows,axis=1)
# Out:
# 这是data:  ['13823509060', '17112542555']
# 发现多电话数据:  author                             ["陈妙虹", "姚奕玲", "林勤", "曾键", "张国明"]
# date                                                      2021-10-25
# pdf_url            http://download.meddata.com.cn:8087/getCore/do...
# file_name                             生物素酶缺乏相关视神经萎缩一例_2021-10-25.pdf
# need_pay                                                         NaN
# doctor_info        ['作者:\xa0张国明,\xa0Email:\xa013823509060@163.com...
# phones                                       13823509060/17112542555
# identify_status                                                 识别成功
# spider_date                                             202301301834
# commit_status                                                    未提交
# content_size                                                     NaN
# re_down                                                          NaN
# origin_moudle                                         全库_病_2021年_win
# ...

# %%
data_list
# Out:
# [['["冯婧", "张鹏", "吴雪", "楚伟可", "张依恋", "李萍"]',
#   '2021-12-15',
#   'http://download.meddata.com.cn:8087/getCore/downloadCore?id=1346288&loginName=hzsf&token=309075c21f204ff6041662cb6433b91fcc',
#   '失代偿性肝硬化急性肾损伤进展为慢性肾脏病的临床特征及其对预后的影响_2021-12-15.pdf',
#   nan,
#   "['作者: 李萍, Email: tjlplxg@163.com, 电话: 13920265719\\n【引用本文】  中文:冯婧,张鹏,吴雪,等. 失代偿性肝硬化急性肾损伤进展为慢性肾脏病的临床特', '作者贡献声明  冯婧:研究设计和实施、论文撰写、数据整理;张鹏:\\n行政和技术支持;吴雪:统计学分析;楚伟可、张依恋:数据采集;李']",
#   '13920265719',
#   '识别成功',
#   202301301819,
#   '未提交',
#   nan,
#   nan,
#   '全库_病_2021年_win',
#   1346288,
#   '6849_杭州师范大学附属医院',
#   '中华消化杂志',
#   '中华医学期刊全文数据库',
#   2021,
#   154],
#  ['["包相华", "毕珂", "史懋功"]',
#   '2021-12-20',
#   'http://download.meddata.com.cn:8087/getCore/downloadCore?id=1346460&loginName=hzsf&token=309075c21f204ff6041662cb6433b91fcc',
#   '山东省烟台市布鲁氏菌病发病状况调查及临床特征分析_2021-12-20.pdf',
#   nan,
#   nan,
#   '13954566369',
#   '识别成功',
#   202301301820,
#   '未提交',
#   nan,
#   nan,
#   '全库_病_2021年_win',
#   1346460,
# ...

# %%
len(data_list)
# Out:
# 11466

# %%
new_df = pd.DataFrame(data_list)

# %%
new_df.head(40)
# Out:
#                                                    0           1   \
# 0              ["冯婧", "张鹏", "吴雪", "楚伟可", "张依恋", "李萍"]  2021-12-15
# 1                                ["包相华", "毕珂", "史懋功"]  2021-12-20
# 2           ["项艺", "吴雯玥", "张倩倩", "王泽学", "张辅民", "孔德润"]  2021-12-15
# 3                                ["黄磊杰", "范建高", "曾静"]  2021-12-15
# 4                         ["潘如菁", "宣暄", "吕明芬", "刘晶晶"]  2021-12-25
# 5                                      ["伍南臻", "龙波玲"]  2021-12-01
# 6                                       ["操雪", "楚天舒"]  2021-12-01
# 7   ["贺彩妮", "杜虹", "牛迎花", "赵文轩", "高宁", "李慎", "黄娜", ...  2021-12-15
# 8                                                 NaN  2021-12-25
# 9                         ["康浩", "杨彩红", "陈语嫣", "李梅华"]  2021-12-20
# 10                          ["顾颖杰", "周开", "蔡飞", "沈潜"]  2021-12-25
# 11                        ["庞远建", "吴长新", "王利花", "王晶"]  2021-12-15
# 12                  ["陈妙虹", "姚奕玲", "林勤", "曾键", "张国明"]  2021-10-25
# ...

# %%
writer = pd.ExcelWriter(r'yiigle_split_phones.xlsx')
new_df.to_excel(writer,encoding='utf-8',index=False)
writer.save()
writer.close()
# Out:
# C:\Users\hello\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
# C:\Users\hello\AppData\Local\Temp\ipykernel_6540\2796636759.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
new_df.head()
# Out:
#                                           0           1   \
# 0     ["冯婧", "张鹏", "吴雪", "楚伟可", "张依恋", "李萍"]  2021-12-15
# 1                       ["包相华", "毕珂", "史懋功"]  2021-12-20
# 2  ["项艺", "吴雯玥", "张倩倩", "王泽学", "张辅民", "孔德润"]  2021-12-15
# 3                       ["黄磊杰", "范建高", "曾静"]  2021-12-15
# 4                ["潘如菁", "宣暄", "吕明芬", "刘晶晶"]  2021-12-25
#
#                                                   2   \
# 0  http://download.meddata.com.cn:8087/getCore/do...
# 1  http://download.meddata.com.cn:8087/getCore/do...
# 2  http://download.meddata.com.cn:8087/getCore/do...
# 3  http://download.meddata.com.cn:8087/getCore/do...
# 4  http://download.meddata.com.cn:8087/getCore/do...
#
#                                                   3   4   \
# 0   失代偿性肝硬化急性肾损伤进展为慢性肾脏病的临床特征及其对预后的影响_2021-12-15.pdf NaN
# 1            山东省烟台市布鲁氏菌病发病状况调查及临床特征分析_2021-12-20.pdf NaN
# 2  可充气球囊压迫辅助下硬化剂注射治疗38例食管-胃底静脉曲张的疗效评价_2021-12-15.pdf NaN
# 3                 青蒿琥酯对非酒精性脂肪性肝病的治疗作用_2021-12-15.pdf NaN
# ...

# %%
df_json = pd.read_json('./cmeg.json',lines=True)

# %%
df_json.head()
# Out:
#                                     _id             unit other_leader  \
# 0  {'$oid': '6305d69317982bc25053a76f'}  北京大学口腔医学院口腔颌面外科          俞光岩
# 1  {'$oid': '6305d69317982bc25053a770'}  北京大学口腔医学院口腔颌面外科          俞光岩
# 2  {'$oid': '6305d69317982bc25053a771'}     中山大学第一医院肾脏内科           陈崴
# 3  {'$oid': '6305d69317982bc25053a772'}        北京协和医院妇产科          郎景和
# 4  {'$oid': '6305d69317982bc25053a773'}        北京协和医院妇产科          郎景和
#
#   other_leader_phone                    title leader leader_phone  \
# 0  010-62179977-5295       美学区域软硬组织增量技术及新技术进展    邱立新  13910564471
# 1  010-62179977-5295      北京大学口腔医院正颌外科基础技术学习班    李自力  13901391680
# 2        13924150966               腹膜透析新进展学习班     陈崴  13924150966
# 3       010-65296201             妇科肿瘤手术学高级培训班     吴鸣  13801224549
# 4       010-65296201  多学科在围产保健管理中的应用实践（技术）学习班    马良坤  13021961166
#
#                 days  place           score   target_stu stu_nums
# 0  \n\t\t2022/04/08-     北京  \n\t\t4分/期\n\t  相关专业的继续教育对象     30/期
# ...

# %%
writer = pd.ExcelWriter(r'cmeg_old.xlsx')
df_json.to_excel(writer,encoding='utf-8',index=False)
writer.save()
writer.close()
# Out:
# C:\Users\hello\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
# C:\Users\hello\AppData\Local\Temp\ipykernel_6540\4229654200.py:3: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
