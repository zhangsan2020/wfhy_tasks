# %%
import pymongo
import pandas as pd

# %%
def get_sqldata(db,col):
#     mongo_cli = pymongo.MongoClient('47.93.86.81',27017)
    mongo_cli = pymongo.MongoClient(host='47.93.86.81',port= 27017,maxConnecting=50,authSource=db,username='zl',password='jiamianwuke2018')

    col = mongo_cli[db][col]
    df = pd.DataFrame(list(col.find()))
    print(df)
    return df

# %%
df = get_sqldata('wfhy_commit','zw_commit')
df.info()

# %% [markdown]
# ### 根据手机号去重

# %% [markdown]
# ## 分割手机号,得出11位数字的手机号码, 方便清洗, 否则部分 +86 xx 和  86 xx难以去重

# %%
df['phone'] = df.phone.map(lambda x: x.split(' ')[1] if len(x.split(' ')) > 1 else x)

# %%
df.head()
# Out:
#                         _id      name        phone                 email  \
# 0  6324109ca99ab100a9383637  热孜万古丽·艾尼  18999169895   18999169895@163.com
# 1  6324109ca99ab100a9383638        杜蓉  18699197889   18999169895@163.com
# 2  6324109ca99ab100a9383639       熊俊成  13968878052    xjc040402@sina.com
# 3  6324109ca99ab100a938363a        巩涛  18615647616  haitao880801@126.com
# 4  6324109ca99ab100a938363b        罗芹  13597807761        qinrms@163.com
#
#     spider_date                                         detail_url  url_id  \
# 0  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177305
# 1  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177305
# 2  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177303
# 3  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177300
# 4  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177298
#
#   commit_status   commit_date
# 0           已提交  202209091818
# 1           已提交  202209091818
# 2           已提交  202209091818
# 3           已提交  202209091818
# 4           已提交  202209091818

# %% [markdown]
# ## 判断真实手机号:  手机字符串包含为 (以 1 开始,其后有10位数字)

# %%
new_df = df[df.phone.str.contains('1(\d+){10}')]
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2300\1980550809.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   new_df = df[df.phone.str.contains('1(\d+){10}')]

# %%
new_df.head()
# Out:
#                         _id      name        phone                 email  \
# 0  6324109ca99ab100a9383637  热孜万古丽·艾尼  18999169895   18999169895@163.com
# 1  6324109ca99ab100a9383638        杜蓉  18699197889   18999169895@163.com
# 2  6324109ca99ab100a9383639       熊俊成  13968878052    xjc040402@sina.com
# 3  6324109ca99ab100a938363a        巩涛  18615647616  haitao880801@126.com
# 4  6324109ca99ab100a938363b        罗芹  13597807761        qinrms@163.com
#
#     spider_date                                         detail_url  url_id  \
# 0  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177305
# 1  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177305
# 2  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177303
# 3  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177300
# 4  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...  177298
#
#   commit_status   commit_date
# 0           已提交  202209091818
# 1           已提交  202209091818
# 2           已提交  202209091818
# 3           已提交  202209091818
# 4           已提交  202209091818

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74687 entries, 0 to 74691
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            74687 non-null  object
#  1   name           74687 non-null  object
#  2   phone          74687 non-null  object
#  3   email          74687 non-null  object
#  4   spider_date    74687 non-null  object
#  5   detail_url     74687 non-null  object
#  6   url_id         74687 non-null  int64
#  7   commit_status  74687 non-null  object
#  8   commit_date    74687 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 5.7+ MB

# %%
new_df
# Out:
#                             _id      name        phone  \
# 0      6324109ca99ab100a9383637  热孜万古丽·艾尼  18999169895
# 1      6324109ca99ab100a9383638        杜蓉  18699197889
# 2      6324109ca99ab100a9383639       熊俊成  13968878052
# 3      6324109ca99ab100a938363a        巩涛  18615647616
# 4      6324109ca99ab100a938363b        罗芹  13597807761
# ...                         ...       ...          ...
# 74687  634d03df922cdfa593b8f63f        张骞  15828107909
# 74688  634d03df922cdfa593b8f641       董燕燕  15989225237
# 74689  634d03df922cdfa593b8f643       于红静  13710859945
# 74690  634d03e6922cdfa593b8f645        郑超  18857116176
# 74691  634d03e6922cdfa593b8f647        郑超  18857116176
#
#                           email   spider_date  \
# 0           18999169895@163.com  202209131109
# 1           18999169895@163.com  202209131109
# 2            xjc040402@sina.com  202209131109
# 3          haitao880801@126.com  202209131109
# 4                qinrms@163.com  202209131109
# ...                         ...           ...
# 74687  zhangqian.97@foxmail.com  202210171527
# 74688         1144725495@qq.com  202210171527
# 74689         1144725495@qq.com  202210171527
# 74690       wallbb_1022@163.com  202210171527
# 74691       wallbb_1022@163.com  202210171527
#
#                                               detail_url  url_id  \
# 0      http://www.chictr.org.cn/showproj.aspx?proj=17...  177305
# 1      http://www.chictr.org.cn/showproj.aspx?proj=17...  177305
# 2      http://www.chictr.org.cn/showproj.aspx?proj=17...  177303
# 3      http://www.chictr.org.cn/showproj.aspx?proj=17...  177300
# 4      http://www.chictr.org.cn/showproj.aspx?proj=17...  177298
# ...                                                  ...     ...
# 74687  http://www.chictr.org.cn/showproj.aspx?proj=18...  183084
# 74688  http://www.chictr.org.cn/showproj.aspx?proj=18...  183085
# 74689  http://www.chictr.org.cn/showproj.aspx?proj=18...  183085
# 74690  http://www.chictr.org.cn/showproj.aspx?proj=18...  183088
# 74691  http://www.chictr.org.cn/showproj.aspx?proj=18...  183088
#
#       commit_status   commit_date
# 0               已提交  202209091818
# 1               已提交  202209091818
# 2               已提交  202209091818
# 3               已提交  202209091818
# 4               已提交  202209091818
# ...             ...           ...
# 74687           未提交
# 74688           未提交
# 74689           未提交
# 74690           未提交
# 74691           未提交
#
# [74687 rows x 9 columns]

# %% [markdown]
# ## 根据手机号去重,保留重复号码的第一个手机号, 这里注意keep参数，等于last为保留最后一行重复项

# %%
new_df.drop_duplicates(subset='phone',inplace=True,keep='first')
# Out:
# C:\python\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
new_df
# Out:
#                             _id      name        phone                 email  \
# 0      6324109ca99ab100a9383637  热孜万古丽·艾尼  18999169895   18999169895@163.com
# 1      6324109ca99ab100a9383638        杜蓉  18699197889   18999169895@163.com
# 2      6324109ca99ab100a9383639       熊俊成  13968878052    xjc040402@sina.com
# 3      6324109ca99ab100a938363a        巩涛  18615647616  haitao880801@126.com
# 4      6324109ca99ab100a938363b        罗芹  13597807761        qinrms@163.com
# ...                         ...       ...          ...                   ...
# 74679  634d03dc922cdfa593b8f62f        张鹏  18834180218     2545785855@qq.com
# 74683  634d03dd922cdfa593b8f637       何家鸣  13826037809       93208383@qq.com
# 74688  634d03df922cdfa593b8f641       董燕燕  15989225237     1144725495@qq.com
# 74689  634d03df922cdfa593b8f643       于红静  13710859945     1144725495@qq.com
# 74690  634d03e6922cdfa593b8f645        郑超  18857116176   wallbb_1022@163.com
#
#         spider_date                                         detail_url  \
# 0      202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 1      202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 2      202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 3      202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 4      202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# ...             ...                                                ...
# 74679  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74683  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74688  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74689  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74690  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
#
#        url_id commit_status   commit_date
# 0      177305           已提交  202209091818
# 1      177305           已提交  202209091818
# 2      177303           已提交  202209091818
# 3      177300           已提交  202209091818
# 4      177298           已提交  202209091818
# ...       ...           ...           ...
# 74679  183080           未提交
# 74683  183082           未提交
# 74688  183085           未提交
# 74689  183085           未提交
# 74690  183088           未提交
#
# [71297 rows x 9 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71297 entries, 0 to 74690
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            71297 non-null  object
#  1   name           71297 non-null  object
#  2   phone          71297 non-null  object
#  3   email          71297 non-null  object
#  4   spider_date    71297 non-null  object
#  5   detail_url     71297 non-null  object
#  6   url_id         71297 non-null  int64
#  7   commit_status  71297 non-null  object
#  8   commit_date    71297 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 5.4+ MB

# %%
new_df_1 = new_df[new_df['commit_status'] == '未提交']

# %%
new_df_1.count()
# Out:
# _id              2329
# name             2329
# phone            2329
# email            2329
# spider_date      2329
# detail_url       2329
# url_id           2329
# commit_status    2329
# commit_date      2329
# dtype: int64

# %% [markdown]
# ## 简单查阅是否还有重复

# %%
new_df_1[new_df_1['email']=="2632494613@qq.com"]
# Out:
# Empty DataFrame
# Columns: [_id, name, phone, email, spider_date, detail_url, url_id, commit_status, commit_date]
# Index: []

# %%
new_df[new_df.phone == '13596052383']
# Out:
#                             _id name        phone              email  \
# 44023  6324109ca99ab100a938e22e  宋春莉  13596052383  2632494613@qq.com
#
#         spider_date                                         detail_url  \
# 44023  202209141309  http://www.chictr.org.cn/showproj.aspx?proj=38764
#
#        url_id commit_status   commit_date
# 44023   38764           已提交  202209091818

# %%
new_df_1.head()
# Out:
#                             _id name        phone                email  \
# 68968  632411bba99ab100a939467f  贾克文  13191470527    3392459514@qq.com
# 68969  632411bba99ab100a9394680   周恒  15854077125    2559650050@qq.com
# 68970  632411bba99ab100a9394681   周云  18715154895      zhoukeg@163.com
# 68971  632411bba99ab100a9394682  王思蒙  18811022134  18811022134@163.com
# 68972  632411bba99ab100a9394683   徐娟  13637066251        xujed@163.com
#
#         spider_date                                         detail_url  \
# 68968  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68969  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68970  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68971  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68972  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
#
#        url_id commit_status commit_date
# 68968  177766           未提交
# 68969  177765           未提交
# 68970  177764           未提交
# 68971  177763           未提交
# 68972  177755           未提交

# %%
new_df_1
# Out:
#                             _id name        phone                email  \
# 68968  632411bba99ab100a939467f  贾克文  13191470527    3392459514@qq.com
# 68969  632411bba99ab100a9394680   周恒  15854077125    2559650050@qq.com
# 68970  632411bba99ab100a9394681   周云  18715154895      zhoukeg@163.com
# 68971  632411bba99ab100a9394682  王思蒙  18811022134  18811022134@163.com
# 68972  632411bba99ab100a9394683   徐娟  13637066251        xujed@163.com
# ...                         ...  ...          ...                  ...
# 74679  634d03dc922cdfa593b8f62f   张鹏  18834180218    2545785855@qq.com
# 74683  634d03dd922cdfa593b8f637  何家鸣  13826037809      93208383@qq.com
# 74688  634d03df922cdfa593b8f641  董燕燕  15989225237    1144725495@qq.com
# 74689  634d03df922cdfa593b8f643  于红静  13710859945    1144725495@qq.com
# 74690  634d03e6922cdfa593b8f645   郑超  18857116176  wallbb_1022@163.com
#
#         spider_date                                         detail_url  \
# 68968  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68969  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68970  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68971  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# 68972  202209131109  http://www.chictr.org.cn/showproj.aspx?proj=17...
# ...             ...                                                ...
# 74679  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74683  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74688  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74689  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74690  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
#
#        url_id commit_status commit_date
# 68968  177766           未提交
# 68969  177765           未提交
# 68970  177764           未提交
# 68971  177763           未提交
# 68972  177755           未提交
# ...       ...           ...         ...
# 74679  183080           未提交
# 74683  183082           未提交
# 74688  183085           未提交
# 74689  183085           未提交
# 74690  183088           未提交
#
# [2329 rows x 9 columns]

# %%
new_df_2 = new_df_1[new_df_1['url_id'] > 177307]

# %%
new_df_2.tail()
# Out:
#                             _id name        phone                email  \
# 74679  634d03dc922cdfa593b8f62f   张鹏  18834180218    2545785855@qq.com
# 74683  634d03dd922cdfa593b8f637  何家鸣  13826037809      93208383@qq.com
# 74688  634d03df922cdfa593b8f641  董燕燕  15989225237    1144725495@qq.com
# 74689  634d03df922cdfa593b8f643  于红静  13710859945    1144725495@qq.com
# 74690  634d03e6922cdfa593b8f645   郑超  18857116176  wallbb_1022@163.com
#
#         spider_date                                         detail_url  \
# 74679  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74683  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74688  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74689  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
# 74690  202210171527  http://www.chictr.org.cn/showproj.aspx?proj=18...
#
#        url_id commit_status commit_date
# 74679  183080           未提交
# 74683  183082           未提交
# 74688  183085           未提交
# 74689  183085           未提交
# 74690  183088           未提交

# %%
new_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 68968 to 74690
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            2329 non-null   object
#  1   name           2329 non-null   object
#  2   phone          2329 non-null   object
#  3   email          2329 non-null   object
#  4   spider_date    2329 non-null   object
#  5   detail_url     2329 non-null   object
#  6   url_id         2329 non-null   int64
#  7   commit_status  2329 non-null   object
#  8   commit_date    2329 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 182.0+ KB

# %%
def to_monogo(df):
    mongo_client = pymongo.MongoClient('localhost', 27017)
    db = mongo_client['wfhy_commit']
    mycol = db['chictr_commit']
    data = df.to_dict(orient='record')
    mycol.insert_many(data)

# %% [markdown]
# ## 保存到excel中

# %% [markdown]
# ## 摘取部分数据进行存储

# %%
writer = pd.ExcelWriter(r'chictr_20221017_2.xlsx', options={'strings_to_urls': False})
new_df_2.to_excel(writer,encoding='utf-8',index=False)
writer.save()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2300\1717719978.py:1: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.
#   writer = pd.ExcelWriter(r'chictr_20221017_2.xlsx', options={'strings_to_urls': False})

# %%
writer.close()
